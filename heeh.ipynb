# %%
# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation

import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
housing =pd.DataFrame(pd.read_csv("house_listingskenya.csv"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 housing =pd.DataFrame(pd.read_csv("house_listingskenya.csv"))
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'house_listingskenya.csv'

# %%
housing.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 housing.head()
#
# NameError: name 'housing' is not defined

# %%
housing.shape
# Out:
# (16117, 17)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16117 entries, 0 to 16116
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               16117 non-null  int64
#  1   price            16114 non-null  float64
#  2   price_qualifier  7247 non-null   object
#  3   bedrooms         16117 non-null  int64
#  4   bathrooms        16117 non-null  int64
#  5   toilets          6089 non-null   float64
#  6   furnished        16117 non-null  int64
#  7   serviced         16117 non-null  int64
#  8   shared           16117 non-null  int64
#  9   parking          16117 non-null  int64
#  10  category         16117 non-null  object
#  11  type             16117 non-null  object
#  12  sub_type         6300 non-null   object
#  13  state            16117 non-null  object
#  14  locality         16111 non-null  object
#  15  sub_locality     1046 non-null   object
#  16  listdate         16117 non-null  object
# dtypes: float64(2), int64(7), object(8)
# memory usage: 2.1+ MB

# %%
housing.describe()
# Out:
#                  id         price      bedrooms     bathrooms      toilets  \
# count  16117.000000  1.611400e+04  16117.000000  16117.000000  6089.000000
# mean    8060.895328  2.263171e+07      2.265868      1.786809     3.175562
# std     4655.115101  7.392285e+07      9.966560      2.292134    14.319435
# min        1.000000  0.000000e+00      0.000000      0.000000     0.000000
# 25%     4030.000000  1.000000e+05      0.000000      0.000000     2.000000
# 50%     8059.000000  3.000000e+06      2.000000      1.000000     3.000000
# 75%    12095.000000  1.750000e+07      4.000000      3.000000     4.000000
# max    16124.000000  3.000000e+09   1231.000000    100.000000  1101.000000
#
#           furnished      serviced        shared       parking
# count  16117.000000  16117.000000  16117.000000  1.611700e+04
# mean       0.042750      0.051188      0.003971  5.221860e+04
# std        0.202299      0.220388      0.062892  5.771765e+06
# min        0.000000      0.000000      0.000000  0.000000e+00
# 25%        0.000000      0.000000      0.000000  0.000000e+00
# 50%        0.000000      0.000000      0.000000  0.000000e+00
# 75%        0.000000      0.000000      0.000000  2.000000e+00
# max        1.000000      1.000000      1.000000  7.231109e+08

# %%
housing.isnull().sum()
# Out:
# id                     0
# price                  3
# price_qualifier     8870
# bedrooms               0
# bathrooms              0
# toilets            10028
# furnished              0
# serviced               0
# shared                 0
# parking                0
# category               0
# type                   0
# sub_type            9817
# state                  0
# locality               6
# sub_locality       15071
# listdate               0
# dtype: int64

# %%
housing['price'].fillna(housing['price'].mean(), inplace=True)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16117 entries, 0 to 16116
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               16117 non-null  int64
#  1   price            16117 non-null  float64
#  2   price_qualifier  7247 non-null   object
#  3   bedrooms         16117 non-null  int64
#  4   bathrooms        16117 non-null  int64
#  5   toilets          6089 non-null   float64
#  6   furnished        16117 non-null  int64
#  7   serviced         16117 non-null  int64
#  8   shared           16117 non-null  int64
#  9   parking          16117 non-null  int64
#  10  category         16117 non-null  object
#  11  type             16117 non-null  object
#  12  sub_type         6300 non-null   object
#  13  state            16117 non-null  object
#  14  locality         16111 non-null  object
#  15  sub_locality     1046 non-null   object
#  16  listdate         16117 non-null  object
# dtypes: float64(2), int64(7), object(8)
# memory usage: 2.1+ MB

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'bedrooms', y = 'price', data = housing)
plt.subplot(2,3,2)
sns.boxplot(x = 'bathrooms', y = 'price', data = housing)
plt.subplot(2,3,3)
sns.boxplot(x = 'parking', y = 'price', data = housing)
plt.subplot(2,3,4)
sns.boxplot(x = 'toilets', y = 'price', data = housing)
plt.subplot(2,3,5)
sns.boxplot(x = 'furnished', y = 'price', data = housing)
plt.subplot(2,3,6)
sns.boxplot(x = 'serviced', y = 'price', data = housing)

plt.show()

# %%
condition = housing['bedrooms'] < 30
df = housing[condition]

condition2 = df['bathrooms'] < 15
condition3 = df['parking'] < 20
condition4 = df['toilets'] < 10

combined_condition = condition2 & condition3 & condition4
df = df[combined_condition]

# %%
new_data = pd.DataFrame({'type': ['House'], 'bedrooms': [3],
                         'category': ['For_Rent'], 'state': ['Nairobi'], 'locality': ['Muthaiga'],
                         'bathrooms': [3], 'toilets': [3], 'furnished': [1], 'serviced': [0], 'shared': [0],
                         'parking': [0], 'sub_type': ['Unknown'],
})

if 'For_Rent' in new_data['category'].values:
    df = df.loc[df['price'] < 2000000]
    print("final1")
else:
    df = df.loc[df['price'] < 200000000]
    print("final2")
# Out:
# final1

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'bedrooms', y = 'price', data = df)
plt.subplot(2,3,2)
sns.boxplot(x = 'bathrooms', y = 'price', data = df)
plt.subplot(2,3,3)
sns.boxplot(x = 'parking', y = 'price', data = df)
plt.subplot(2,3,4)
sns.boxplot(x = 'toilets', y = 'price', data = df)
plt.subplot(2,3,5)
sns.boxplot(x = 'furnished', y = 'price', data = df)
plt.subplot(2,3,6)
sns.boxplot(x = 'serviced', y = 'price', data = df)

plt.show()

# %%
df.shape
# Out:
# (3297, 17)

# %%
df.isnull().sum()
# Out:
# id                    0
# price                 0
# price_qualifier     111
# bedrooms              0
# bathrooms             0
# toilets               0
# furnished             0
# serviced              0
# shared                0
# parking               0
# category              0
# type                  0
# sub_type           2175
# state                 0
# locality              1
# sub_locality       3061
# listdate              0
# dtype: int64

# %%
del df["id"]
del df["price_qualifier"]
del df["sub_locality"]

# %%
df.shape
# Out:
# (3297, 14)

# %%
df['toilets'].fillna(df['toilets'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# price           0
# bedrooms        0
# bathrooms       0
# toilets         0
# furnished       0
# serviced        0
# shared          0
# parking         0
# category        0
# type            0
# sub_type     2175
# state           0
# locality        1
# listdate        0
# dtype: int64

# %%
df.shape
# Out:
# (3297, 14)

# %%
df['sub_type'].fillna('Unknown', inplace=True)
df['locality'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# price        0
# bedrooms     0
# bathrooms    0
# toilets      0
# furnished    0
# serviced     0
# shared       0
# parking      0
# category     0
# type         0
# sub_type     0
# state        0
# locality     0
# listdate     0
# dtype: int64

# %%
from datetime import datetime
df['listdate'] = pd.to_datetime(df['listdate'])
df['listyear'] = df['listdate'].dt.year.astype(float)
df['listmonth'] = df['listdate'].dt.month.astype(float)

# %%
del df["listdate"]

# %%
df['listyear'].fillna(df['listyear'].mean(), inplace=True)
df['listmonth'].fillna(df['listmonth'].mean(), inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
categorical_columns = ['category','sub_type','locality','type','state',]

for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
condition2= df['category']<2
condition3= df['type']<3
condition4= df['shared']<1



combined_condition= condition2&condition3&condition4
df= df[combined_condition]

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'category', y = 'price', data = df)
plt.subplot(2,3,2)
sns.boxplot(x = 'sub_type', y = 'price', data = df)
plt.subplot(2,3,3)
sns.boxplot(x = 'locality', y = 'price', data = df)
plt.subplot(2,3,4)
sns.boxplot(x = 'type', y = 'price', data = df)
plt.subplot(2,3,5)
sns.boxplot(x = 'state', y = 'price', data = df)
plt.subplot(2,3,6)
sns.boxplot(x = 'listmonth', y = 'price', data = df)

plt.show()

# %%
import pandas as pd

y = df['price']
x = df.drop(['price', 'listmonth', 'listyear'], axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=45)

# %%
#Data scaling for 
from sklearn.preprocessing import Normalizer

scaler = Normalizer()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#Data encoding
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
categorical_columns = ['category','sub_type','locality','type','state']

for column in categorical_columns:
    new_data[column] = label_encoder.fit_transform(new_data[column])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 categorical_columns = ['category','sub_type','locality','type','state']
#       6 for column in categorical_columns:
# ----> 7     new_data[column] = label_encoder.fit_transform(new_data[column])
#
# NameError: name 'new_data' is not defined

# %%
from sklearn.preprocessing import Normalizer

scaler = Normalizer()
new_data2 = scaler.fit_transform(new_data)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 4930829129.019379

# %%
rmse = np.sqrt(mse)

# %%
print(rmse)
# Out:
# 70219.86278126281

# %%
modpred= model.predict(new_data2)

# %%
print(modpred)
# Out:
# [409330.12]

# %%
modpred= modpred.astype(int)
